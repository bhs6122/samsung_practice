# %%
#   012
#   abc     3글자 가운데는 1    3나누기2 = 1.5 -> 소수점제거 -> 1
#   01234   
#   abcde   5글자 가운데는 2    5나누기2 = 2.5 -> 소수점제거 -> 2

def 가운데(text):
    길이 = len(text)
    중앙 = 길이 // 2
    return text[중앙]
가운데('abcde')
# Out:
# 'c'

# %%
def 수박(n):
    text = '수박'
    if n % 2 == 0:
        return text * (n // 2)

# %%
outer_a = 0

def func(a):
    outer_a = a + 2
    print('함수 내부', outer_a)

func(10)
print('함수 외부', outer_a)
# Out:
# 함수 내부 12
# 함수 외부 0

# %%
def a(n):
    if n == 1:
        print('종료')
        return
    a(n - 1)
a(5)
# Out:
# 종료

# %%
def factorial(n):
    if n > 0:
        return n * factorial(n - 1)
    else:
        return 1

factorial(5)
# Out:
# 120

# %%
def gcd(a, b):
    if a % b == 0:
        return b
    return gcd(b, a % b)
gcd(192, 162)
# Out:
# 6

# %%
plus = lambda a, b: a + b
result = plus(10, 20)

print(result)
# Out:
# 30

# %%
words= ["banana", "apple", "cherry", "date"]
# 문자열 길이 기준으로 정렬
words.sort(key=lambda w: len(w))
print(words) # ['date', 'apple', 'banana', 'cherry']
# Out:
# ['date', 'apple', 'banana', 'cherry']

# %%
def 함수(w):
    return len(w)

words.sort(key = 함수)

# %%
# map: 모든 원소에 함수 적용
nums = [1, 2, 3, 4, 5]
squared = list(map(lambda x: x**2, nums))
print(squared) # [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %%
# map: 모든 원소에 함수 적용
nums = [1, 2, 3, 4, 5]
squared = list(map(lambda x: str(x**2), nums))
print(squared) # [1, 4, 9, 16, 25]
# Out:
# ['1', '4', '9', '16', '25']

# %%
#연습문제
#문자열의 길이를 반환하는 lambda 함수 작성하기

string_length = ( )
print(string_length("hello"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       1 #연습문제
#       2 #문자열의 길이를 반환하는 lambda 함수 작성하기
#       3
#       4 string_length = ( )
# ----> 5 print(string_length("hello"))
#       6
#       7
#
# TypeError: 'tuple' object is not callable

# %%
check_even_odd = lambda x: '짝' if x % 2 == 0 else '홀'
print(check_even_odd(7))
print(check_even_odd(10))
# Out:
# 홀
# 짝

# %%
#아래의 함수를 lambda와 List Comprehension을 사용하는 함수로 작성
def myfunc(numbers):
    result= []
    for number in numbers:
        if number > 5:
            result.append(number)
    return result

result= myfunc([2, 3, 4, 5, 6, 7, 8])
print(result)
# Out:
# [6, 7, 8]

# %%
myfunc = lambda numbers: [ n for n in numbers if n > 5 ]

result= myfunc([2, 3, 4, 5, 6, 7, 8])
print(result)
# Out:
# [6, 7, 8]

# %%
#연습문제
#두 수를 입력받은 후 덧셈 결과 출력하기

input1 = input('숫자1 입력: ')
input2 = input('숫자2 입력: ')
#코드 작성
result = int(input1) + int(input2)

print('합계:', result)

# %%
#연습문제
#아래와 같이 숫자들을 입력한 후 입력된 숫자들의 합 구하기

# "23, 24, 1, 9, 11, 26"
text = input('입력: ')
text = text.split(', ')
text = [ int(n) for n in text ]
print(text)
total = sum(text)

print('합계:', total)
# Out:
# [23, 24, 1, 9, 11, 26]
# 합계: 94

# %%
for i in range(1, 11):
    print(str(i) + '번째', end = ' ')
# Out:
# 1번째 2번째 3번째 4번째 5번째 6번째 7번째 8번째 9번째 10번째

# %%
# 연습문제
# 반복문과 print 함수를 이용하여 아래와 같은 모습 출력하기

n = 5

# 코드 작성

for i in range(n):
    left여백 = 3 - i    # 2 1 0
    for j in range(n):
        print(' ' * left여백 + '*', end = '')
    print()
# Out:
#    *   *   *   *   *
#   *  *  *  *  *
#  * * * * *
# *****
# *****

# %%
file = open('test.txt', encoding = 'utf-8')
print(file.read())
# Out:
# 1번째
# 2번째
# 3번째
# 4번째
# 5번째
# 6번째
# 7번째
# 8번째

# %%
# for line in file 방식이 제일 좋음 추천

file = open('test.txt', encoding = 'utf8')
for line in file:
    print(line, end = '')
file.close()
# Out:
# 1번째
# 2번째
# 3번째
# 4번째
# 5번째
# 6번째
# 7번째
# 8번째

# %%
file = open('numbers_data.txt', encoding = 'utf8')
for line in file:
    print(line, end = '')
file.close()
# Out:
# 7
# 9
# 24
# 29
# 34
# 38

# %%
# 연습문제
# numbers_data.txt의 내용을 읽은 후 숫자들의 합 구하기
file = open('numbers_data.txt', encoding = 'utf8')
for line in file:
    print(line, end = '')
file.close()
# Out:
# 7
# 9
# 24
# 29
# 34
# 38

# %%
# 연습문제
# text_data.txt의 내용을 읽은 후 알파벳 t가 포함된 단어만 출력하기
file = open('text_data.txt', encoding = 'utf8')
for t in file:
    if 't' in t:
        print(t)
file.close()
# Out:
# python
#
# kotlin
#
# fortran

# %%
f = open('seoul_기온.csv', 'rt')
date_list = []
min_list = []
for data in f:
    #      0      1    2    3
    # 2021-01-02,-5,-8.4,-1.4
    date_list += [data.split(',')[0]]
    min_list.append(data.split(',')[2])
f.close()
date_list = [   date for date in date_list[1:]   ]
min_list = [   float(min) for min in min_list[1:]   ]

import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False
plt.plot(min_list)
plt.xticks(range(len(min_list)), date_list, rotation=45)
plt.show()

# %%
pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ----------------------- ---------------- 5.5/9.5 MB 27.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 25.4 MB/s  0:00:00
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 27.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------------------- -------------------- 6.0/12.6 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 31.0 MB/s eta 0:00:01
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 11.7 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
file = 'shi.jpg'

import base64

file = open(file, 'rb')
base64_string = base64.b64encode(file.read())
file.close()

print('<img src="data:image/png;base64,%s">' % base64_string.decode())
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# <img src="data:image/jpg;base64,...">

# %%
import requests
url = 'http://ggoreb.com/shi/python/shi.jpg'
res = requests.get(url)
res.content
file = open('./shi2.jpg', 'wb')
file.write( res.content )
file.close()

# %%
# 파일쓰기 연습문제 (이미지 다운로드)
#인터넷 주소(URL)에 있는 이미지 파일을 파이썬 코드로 다운로드하여 내 컴퓨터에 python-image.jpg 로 
#저장합니다.

import requests

# 다운로드할 파이썬 로고 이미지 주소입니다.
image_url = "http://ggoreb.com/python/images/python-image.jpg"

print("웹에서 이미지를 요청하는 중...")

# requests를 사용해 이미지 데이터를 가져옵니다.
response = requests.get(image_url)
image_bytes = response.content

print("이미지 다운로드 완료! 이제 파일로 저장합니다...")

# [문제] 받아온 이미지 바이너리 데이터(image_bytes)를 'python-image.jpg' 파일로 저장하기
file = open('./python-iamge.jpg', 'wb')
file.write(image_bytes)
file.close
print("이미지 파일 저장 완료! 폴더에서 이미지 파일을 확인해보세요.")
# Out:
# 웹에서 이미지를 요청하는 중...
# 이미지 다운로드 완료! 이제 파일로 저장합니다...
# 이미지 파일 저장 완료! 폴더에서 이미지 파일을 확인해보세요.

# %%
#파일쓰기 연습문제 (시스템 로그 파일 생성)

#프로그램이 실행되면서 발생하는 가상의 기록(로그)을 system.log 파일에 텍스트 형식으로 누적 저장합니다.
#조건 1) 기존 파일 내용을 지우지 않고 이어서 작성
#조건 2) 각 로그는 줄바꿈하며 한 줄에 하나씩 작성

import datetime

# 현재 날짜와 시간을 구하기
current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                                        #str format time

# 기록할 가짜 로그 데이터
log_messages = [
 "사용자가 관리자 페이지에 로그인했습니다.",
 "데이터베이스 연결에 성공했습니다.",
 "경고: 디스크 용량이 80% 이상 채워졌습니다.",
 "에러: 파일 업로드 중 예기치 못한 오류가 발생했습니다."
]

print("로그 생성을 시작합니다...")

# [문제] 반복문을 사용하여 system.log 파일에 로그를 한 줄씩 누적해서 쓰기
file = open('system.log', 'at', encoding = 'utf8')
for a in log_messages:
    file.write(f'[{current_time}] {a}\n')
file.close

print("로그 파일 작성 완료!")
# Out:
# 로그 생성을 시작합니다...
# 로그 파일 작성 완료!
