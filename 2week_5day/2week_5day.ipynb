# %%
import pymysql
conn = pymysql.connect(
host='svc.sel3.cloudtype.app', user='root', password='1234',
db='BANG', charset='utf8', port = 31776
)
cursor = conn.cursor()
sql = '''
SELECT * FROM 고객
'''
cursor.execute(sql)
result = cursor.fetchall()
for row in result:
    print(row[0], row[1], row[2], row[3])

cursor.close()
conn.close()
# Out:
# apple 김소화 20 gold
# banana 김선우 25 vip
# carrot 고명석 28 gold
# grape  None None
# grape2  None None
# kiwi 박서준 29 gold
# melon 성원용 35 gold
# orange 김용욱 22 silver
# peach 오형준 None silver
# pear 채광주 31 silver
# plum 이하늘 40 vip

# %% [markdown]
# flask 플라스크
# backend 웹서버를 만드는 도구
#
# 웹서버: 브라우저로 접속(요청)할 수 있는 존재
#     -> 코딩으로 웹서버를 만들면 백엔드
#
# 서버는 다양한 메뉴를 제공
#     메뉴 => URL
#         /

# %%
pip install flask
# Out:
# Collecting flask
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting blinker>=1.9.0 (from flask)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from flask)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2.0 (from flask)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from flask)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from flask)
#   Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Collecting werkzeug>=3.1.0 (from flask)
#   Using cached werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: colorama in c:\Users\samsung1\.venv\Lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Using cached flask-3.1.3-py3-none-any.whl (103 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Using cached werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Installing collected packages: markupsafe, itsdangerous, click, blinker, werkzeug, jinja2, flask
#
#    ----------- ---------------------------- 2/7 [click]
#    ----------------- ---------------------- 3/7 [blinker]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------------- ----------- 5/7 [jinja2]
#    ---------------------------- ----------- 5/7 [jinja2]
#    ---------------------------------- ----- 6/7 [flask]
#    ---------------------------------------- 7/7 [flask]
#
# Successfully installed blinker-1.9.0 click-8.4.2 flask-3.1.3 itsdangerous-2.2.0 jinja2-3.1.6 markupsafe-3.0.3 werkzeug-3.1.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql
conn = pymysql.connect(
host='svc.sel3.cloudtype.app', user='root', password='1234',
db='BANG', charset='utf8', port = 31776
)
cursor = conn.cursor()
sql = '''
    select * from assembly_member
    limit 0, 10
'''
cursor.execute(sql)
result = cursor.fetchall()

print(result)

# for row in result:
#     print(row[0], row[1], row[2], row[3])

cursor.close()
conn.close()
# Out:
# ((1, '제헌', 1, 'WQ3523', 'C1J76609', '강기문', '姜己文', None, 0, '남', 'https://www.assembly.go.kr/static/portal/img/openassm/C1J76609.jpg', '101030', '무소속', '경남 산청', '지역구', '초선', '100001', '제헌', None, '재정경제위원회', None, None, None, None, None, None, '1999-00-00', '제헌', None, None), (2, '제헌', 2, 'AT4819', '41F70646', '강달수', '姜達秀', None, 0, '남