# %%
결과 = print('hello')
print(결과)

items = [5, 1, 9]
items.sort()

print(items)
# Out:
# hello
# None
# [1, 5, 9]

# %%
def a():
    print('가')
def b():
    return a
b()()       #()는 실행을 의미
# Out:
# 가

# %%
#연습문제
#그래프와 같이 이동한 거리 dx, dy 를 구할 수 있는 distance() 함수 작성

def distance(start, end):
# 코드 작성
    return abs(start[0] - end[0]), abs(start[1] - end[1])

start = (1, 1)
end = (5, 3)
dx, dy = distance(start, end)
print('dx:', dx, 'dy:', dy)
# Out:
# dx: 4 dy: 2

# %%
s = 3.14

int(s)
# Out:
# 3

# %%
s = "Python"
d = {'a': 1, 'b': 2}

list(s)
list(d)
# Out:
# ['a', 'b']

# %%
# 연습문제
# 리스트 ['사과', '바나나', '포도']를 번호와 함께 출력하기

fruits = ['사과', '바나나', '포도']
for idx, fruit in enumerate(fruits):
    print(idx, fruit)
# Out:
# 0 사과
# 1 바나나
# 2 포도

# %%
# 연습문제
# 주어진 데이터를 결과와 같은 형식의 데이터로 저장하기

fish1_length = [
25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7,
31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5,
34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0,
38.5, 38.5, 39.5, 41.0, 41.0
]
fish1_weight = [
242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0,
500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0,
610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0,
714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0
]
fish2_length = [
9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2,
12.4, 13.0, 14.3, 15.0
]
fish2_weight = [
6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2,
13.4, 12.2, 19.7, 19.9
]

# %%
length = fish1_length + fish2_length
weight = fish1_weight + fish2_weight

# 방법1
# 데이터 = []
# for 결과 in zip(length, weight):
#     데이터.append(list(결과))
# 데이터

# 방법2
[list(결과) for 결과 in zip(length, weight)]
# Out:
# [[25.4, 242.0],
#  [26.3, 290.0],
#  [26.5, 340.0],
#  [29.0, 363.0],
#  [29.0, 430.0],
#  [29.7, 450.0],
#  [29.7, 500.0],
#  [30.0, 390.0],
#  [30.0, 450.0],
#  [30.7, 500.0],
#  [31.0, 475.0],
#  [31.0, 500.0],
#  [31.5, 500.0],
#  [32.0, 340.0],
#  [32.0, 600.0],
#  [32.0, 600.0],
#  [33.0, 700.0],
#  [33.0, 700.0],
#  [33.5, 610.0],
#  [33.5, 650.0],
#  [34.0, 575.0],
#  [34.0, 685.0],
#  [34.5, 620.0],
#  [35.0, 680.0],
#  [35.0, 700.0],
#  [35.0, 725.0],
#  [35.0, 720.0],
#  [36.0, 714.0],
#  [36.0, 850.0],
#  [37.0, 1000.0],
#  [38.5, 920.0],
#  [38.5, 955.0],
#  [39.5, 925.0],
#  [41.0, 975.0],
#  [41.0, 950.0],
#  [9.8, 6.7],
#  [10.5, 7.5],
#  [10.6, 7.0],
#  [11.0, 9.7],
#  [11.2, 9.8],
#  [11.3, 8.7],
#  [11.8, 10.0],
#  [11.8, 9.9],
#  [12.0, 9.8],
#  [12.2, 12.2],
#  [12.4, 13.4],
#  [13.0, 12.2],
#  [14.3, 19.7],
#  [15.0, 19.9]]

# %%
# 연습문제
# 색상표를 통해 확인된 숫자를 16진수로 표현

red = 190
green = 66
blue = 205

# 코드 작성
r = hex(red)
g = hex(green)
b = hex(blue)

print(r, g, b)
# Out:
# 0xbe 0x42 0xcd

# %%
# 연습문제
# 16진수 문자 코드값을 문자로 변환하기

hexa_string = '48 45 4C 4C 4F'

# 코드 작성
# a = hexa_string.split()

# for h in a:
#     s = int(h, 16)
#     print(h, s, chr(s))

#방법2
[ chr(int(h, 16)) for h in hexa_string.split() ]
# Out:
# ['H', 'E', 'L', 'L', 'O']

# %%
def 내꺼(x):    # 매개변수는 1개만 가능
    return str(x) + '@'

items = [1, 2, 3]
list(map(내꺼, items))

#list(map(lambda x: str(x) + '@', items))
# Out:
# ['1@', '2@', '3@']

# %%
def 내꺼(x):
    return x != 2
#   return x % 2 != 0

items = [1, 2, 3]
list(filter(내꺼, items))
# Out:
# [1, 3]

# %%
nums = ['1', '20', '3', '40']
a = list(map(lambda x: int(x), nums))
b = list(filter(lambda x: x >= 10, a))
print(b)
# Out:
# [20, 40]

# %%
nums = [5, 10, 15, 20, 25]
a = list(filter(lambda x: x % 3 == 0, nums))
a = list(map(lambda x: x ** 2, a))
print(a)
# Out:
# [225]

# %%
# 연습문제
# 현재 작업 디렉토리에 "practice" 폴더를 만들고 그 안에"hello.txt" 파일을 생성하기
# "hello.txt" 파일 내용 → Hello, Python!

import os
현재위치 = os.getcwd()
# pathlib : 디렉토리생성
from pathlib import Path
Path("practice").mkdir(exist_ok=True)
f = open('practice/hello.txt', 'wt', encoding = 'utf8')
f.write('Hello, Python!')
f.close()

# %%
# json : 문자열 → 파이썬 객체
import json
data = '{"name":"Alice","age":25}'
obj = json.loads(data)  # 문자 -> 객체
print(obj["name"], obj["age"])

json_text = json.dumps(obj)  # 객체 -> 문자
print(json_text)
# Out:
# Alice 25
# {"name": "Alice", "age": 25}

# %%
import json
data = '[{"id":1,"name":"철수"},{"id":2,"name":"영희"}]'
리스트 = json.loads(data)
[ i['name']for i in 리스트]
# Out:
# ['철수', '영희']

# %%
import time
time.time()     #Unix Time ex) 1970년 1월 1일 00:00:00부터 흘러온 시간(숫자)를 의미

import random
random.random()     # 0 <= X < 1
s = '123'

s[0:2]  # 2포함안함
random.randint(1, 60000)
# Out:
# 39867

# %%
import time
print(1)
time.sleep(3)
print(2)
# Out:
# 1
# 2

# %%
# 연습문제
# 동전 앞/뒤를 무작위로 10번 던져 나온 결과를 리스트로 저장하기

#코드 작성
동전 = ['앞면', '뒷면']
[ random.choice(동전) for a in range(10)]
# Out:
# ['앞면', '뒷면', '앞면', '앞면', '뒷면', '뒷면', '앞면', '뒷면', '앞면', '뒷면']

# %%
# 연습문제
# 주사위를 2개 동시에 던져서
# 두 눈의 합이 7이 될 때까지 반복하고 시도한 횟수 출력하기

# 코드 작성

count = 0
while True:
    a = random.randint(1, 6)
    b = random.randint(1, 6)
    count += 1
    print(f'{a} / {b} 시도 횟수: {count}')
    if a + b == 7: break
# Out:
# 1 / 6 시도 횟수: 1

# %%
import hashlib

old_pwd = '1234'

m = hashlib.sha256()
m.update(old_pwd.encode())
new_pwd = m.hexdigest()

# new_pwd = hashlib.sha256(old_pwd.encode()).hexdigest()

print(new_pwd)
# Out:
# 03ac674216f3e15c761ee1a5e255f067953623c8b388b4459e13f978d7c846f4

# %%
# 정규 표현식 사용을 위한 모듈 import
import re

# 정규 표현식의 규칙 지정
pattern = re.compile(r'[a]')

# 정규 표현식 규칙에 문자열을 입력하여 확인
print(pattern.search('ab'))
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
import re
pattern = re.compile(r'[9012345678]')   # []쓰면 9 or 0 or 1 or 2 or ...를 의미
print(pattern.search('안녕abc123'))
# Out:
# <re.Match object; span=(5, 6), match='1'>

# %%
import re
pattern = re.compile(r'[a-z]')    # a ~ z 까지 범위 지정 가능
print(pattern.search('안녕abc123'))
# Out:
# <re.Match object; span=(2, 3), match='a'>

# %%
import re
pattern = re.compile(r'^[a-z]')     #[^ ] 는 not을 의미
                                    #^[ ] 는 부터 시작을 의미

# %%
# 연습 문제
# 아이디의 유효성 검사하기
# - 조건 1) 아이디의 시작 문자는 영어이어야 한다.
# - 조건 2) 영어와 숫자로만 작성되어야 한다.
# * 힌트) 시작 문자 검사는 match(), 그 외는 search() 사용

import re
pattern1 = re.compile(r'(  ① )')
pattern2 = re.compile(r'(  ②  )')
user_id = '(  ③ )'
result1 = pattern1.match(user_id)
result2 = pattern2.search(user_id)
if (  ④ ):
print(f'{user_id} <- 가입 가능')
else:
print(f'{user_id} <- 가입 불가')

# %%
import re
pattern1 = re.compile(r'[a-zA-Z]')
pattern2 = re.compile(r'[가-힣]')      # "안녕abc12" <=   영어 O, 숫자 O

user_id = 'a12abc'
result1 = pattern1.match(user_id)
result2 = pattern2.search(user_id)
if result1 and not result2:
    print(f'{user_id} <- 가입 가능')
else:
    print(f'{user_id} <- 가입 불가')
# Out:
# a12abc <- 가입 가능

# %%
# 정규 표현식 (Regular Expressions)
# 기호들을 사용한 예시

import re
text = "apple, ape, apricot, banana, apppple"

print(re.search(r"a.p", text)) 
# 'a' + 임의의 문자 + 'p' 
# → <re.Match object; span=(0, 3), match='app'>

print(re.search(r"a[bc]e", "ace abe ace")) 
# a 다음에 b나 c가 오고 e로 끝
# → <re.Match object; span=(0, 3), match='ace'>

print(re.search(r"ap*le", text)) 
# 'a' + 'p' 0회 이상 + 'le'
# → <re.Match object; span=(0, 5), match='apple'>

print(re.search(r"ap+le", text)) 
# 'a' + 'p' 1회 이상 + 'le'
# → <re.Match object; span=(0, 5), match='apple'>

print(re.search(r"ap{2}le", text)) 
# 'a' + 'p' 2번 + 'le'
# → <re.Match object; span=(0, 5), match='apple'>

print(re.search(r"ap?le", text)) 
# 'p'가 0번 또는 1번
# → None

# %%
# 연습문제
# 주민등록번호 유효성 검사하기
# - 조건 1) 앞자리 숫자는 6자리, 뒷자리 숫자는 7자리로 작성되어야 한다.
# - 조건 2) 뒷자리의 시작숫자는 1 ~ 4 이어야 한다

import re
pattern = re.compile(r'[0-9]{6}-[1-4][0-9]{6}')
text = '791111-1234567'
print(text, end=' <- ')
result = pattern.search(text)
if result:
    print('정상')
else:
    print('올바르지 못한 주민등록번호')

# 결과
# text = '791111-1234567' <- 정상
# text = '791111-123456' <- 올바르지 못한 주민등록번호
# text = '791111-5234567 <- 올바르지 못한 주민등록번호
# Out:
# 791111-1234567 <- 정상

# %%
# 연습문제
# 은행 계좌번호 형식 검사하기
# - 조건 1) 숫자 3자리-숫자2자리-숫자6자리
# - 조건 2) 첫번째 3자리 숫자의 시작은 반드시 1 이어야 한다.
# - 조건 3) 두번째 2자리 숫자의 시작은 반드시 1 이어야 한다.

import re
pattern = re.compile(r'^1\d{2}-1\d{1}-\d{6}&')       # {6}& 는 숫자 6자리로 끝나야한다는 의미
text = '123-12-123456'
print(text, end=' <- ')
result = pattern.search(text)
if result:
    print('확인되었습니다.')
else:
    print('계좌번호 다시 확인해주세요.')
# Out:
# 123-12-123456 <- 확인되었습니다.

# %%
# ■연습문제
# ●문자열이 형식에 맞는지 검사하기
# -조건 1) '안녕하세요' 문자로 시작
# -조건 2) 내용 중 '열심히' 문자 포함
# -조건 3) '감사합니다.' 문자로 종료
# ※ . 이 줄바꿈 문자도 매칭되도록 하기 위해 re.DOTALL옵션 사용

import re
pattern = re.compile(r'(  ①  )', re.DOTALL)
text = '''안녕하세요. 저는 OOO에서 태어났고... 
열심히 하겠습니다. 감사합니다.
'''
# 코드 작성( ② )

# %%
import re
pattern = re.compile(r'^안녕하세요.*열심히.*감사합니다[.]', re.DOTALL)
text = '''안녕하세요. 저는 OOO에서 태어났고...
열심히 하겠습니다. 감사합니다.
'''
pattern.search(text)
# Out:
# <re.Match object; span=(0, 41), match='안녕하세요. 저는 OOO에서 태어났고...\n열심히 하겠습니다. 감사합니다.'>

# %%
import re
pattern = re.compile(r'^안녕하세요(.*)열심히.*감사합니다[.]', re.DOTALL)
text = '''안녕하세요. 저는 OOO에서 태어났고...
열심히 하겠습니다. 감사합니다.
'''
r = pattern.search(text)
r.group(1)
# Out:
# '. 저는 OOO에서 태어났고...\n'

# %%
import re
pattern = re.compile(r'^안녕하세요(.*)열심히(.*)감사합니다[.]', re.DOTALL)
text = '''안녕하세요. 저는 OOO에서 태어났고...
열심히 하겠습니다. 감사합니다.
'''
r = pattern.search(text)
print(r.group(1))
print(r.group(2))
# Out:
# . 저는 OOO에서 태어났고...
#
#  하겠습니다.

# %%
# 연습문제
# ●문자열의 내용 중 이름과 전화번호 찾아내기

import re
pattern = re.compile(r'(  ①  )')
text = '''
사용자 정보, 이름: 꼬렙, 전화번호 : 1234, 이메일 : seorab@naver.com
'''
# 코드 작성 (  ②  )

# %%
import re
pattern = re.compile(r'이름\s*:\s*(\w+),\s*전화번호\s*:\s*(\d+)')
text = '''
사용자 정보, 이름: 꼬렙, 전화번호 : 1234, 이메일 : seorab@naver.com
'''

r = pattern.search(text)
print(r.group(1))
print(r.group(2))
# Out:
# 꼬렙
# 1234

# %%
# ■정규 표현식 (Regular Expressions)
# ● findall()
#     - 에러 번호 찾아내기

import re
pattern = re.compile(r'에러\s*\d+')
result = pattern.findall(
'에러 404 : 페이지 없음\n 에러 500 : 서버 오류')
print(result)
# Out:
# ['에러 404', '에러 500']

# %%
import re
pattern = re.compile(r'에러.+:\s*(.+)')
result = pattern.findall(
'에러 404 : 페이지 없음\n 에러 500 : 서버 오류')
print(result)
# Out:
# ['페이지 없음', '서버 오류']

# %%
with open('harry_potter.txt') as file:
    text = file.read()

import re

pattern = re.compile(r'(Harry Potter)', re.I) # 대소문자 무시
len(pattern.findall(text))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 with open('harry_potter.txt') as file:
#       2     text = file.read()
#       3
#       4 import re
#
# FileNotFoundError: [Errno 2] No such file or directory: 'harry_potter.txt'

# %%
# ■연습문제
# ●여러 기호를 제외하고 검색어만 확인하기
# - 조건 1) 검색어는 #기호 다음부터 시작
# - 조건 2) 여러 개의 검색어가 입력될 때는 comma(,)와 공백으로 구분
# - 조건 3) 검색어 구분자 중 공백은 한개 이상이 입력될 수 있음

import re
pattern = re.compile(r'(  ①  )')
text = '#서울, #강남, #맛집, #주꾸미'
res = pattern.findall(text)
print(res)

# %%
import re

pattern = re.compile(r'[^#]+')
text = '#서울, #강남, #맛집, #주꾸미'
res = pattern.findall(text)
print(res)
# Out:
# ['서울, ', '강남, ', '맛집, ', '주꾸미']
