# %%
pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-1.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.13.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx2<3,>=2.0.0 (from anthropic)
#   Downloading httpx2-2.12.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio<2,>=1 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.15)
# Collecting httpcore2==2.12.0 (from httpx2<3,>=2.0.0->anthropic)
#   Downloading httpcore2-2.12.0-py3-none-any.whl.metadata (25 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.19-py3-none-any.whl.metadata (9.2 kB)
# Collecting truststore>=0.10 (from httpx2<3,>=2.0.0->anthropic)
#   Downloading truststore-0.10.4-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: h11>=0.16 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore2==2.12.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\samsung\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-1.4.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 35.1 MB/s  0:00:00
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading httpx2-2.12.0-py3-none-any.whl (95 kB)
# Downloading httpcore2-2.12.0-py3-none-any.whl (83 kB)
# Downloading idna-3.19-py3-none-any.whl (68 kB)
# Downloading truststore-0.10.4-py3-none-any.whl (18 kB)
# Installing collected packages: truststore, idna, docstring-parser, httpcore2, httpx2, anthropic
#
#   Attempting uninstall: idna
#
#     Found existing installation: idna 3.15
#
#     Uninstalling idna-3.15:
#
#       Successfully uninstalled idna-3.15
#
#    ------ --------------------------------- 1/6 [idna]
#    -------------------- ------------------- 3/6 [httpcore2]
#    -------------------- ------------------- 3/6 [httpcore2]
#    -------------------------- ------------- 4/6 [httpx2]
#    -------------------------- ------------- 4/6 [httpx2]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    --------------------------------- ------ 5/6 [anthropic]
#    ---------------------------------------- 6/6 [anthropic]
#
# Successfully installed anthropic-1.4.0 docstring-parser-0.18.0 httpcore2-2.12.0 httpx2-2.12.0 idna-3.19 truststore-0.10.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import anthropic

client = anthropic.Anthropic(api_key = "sk-REPLACE-WITH-YOUR-API-KEY")

message = client.messages.create(
model="claude-sonnet-5",
max_tokens=1024,
messages=[
{"role": "user", "content": "너는누구야?"}
]
) 

print(message.content[0].text)
# Out:
# # 안녕하세요! 👋
#
# 저는 **Claude**입니다. Anthropic에서 개발한 AI 어시스턴트예요.
#
# ## 제가 할 수 있는 일들
#
# - 💬 **대화 및 질문 답변** - 다양한 주제에 대해 이야기 나누기
# - ✍️ **글쓰기 지원** - 이메일, 에세이, 창작물 등 작성 도움
# - 💻 **코딩 도움** - 프로그래밍 문제 해결, 코드 작성/리뷰
# - 📚 **학습 지원** - 개념 설명, 요약, 번역 등
# - 🤔 **분석 및 아이디어** - 문제 해결, 브레인스토밍
#
# ## 참고하실 점
#
# - 실시간 정보 접근은 제한적일 수 있어요
# - 확실하지 않은 내용은 솔직하게 말씀드려요
# - 대화 내용은 세션마다 새로 시작됩니다
#
# 궁금한 점이나 도움이 필요한 일이 있으시면 편하게 말씀해주세요! 😊

# %%
# 키 등록
# 환경변수 편집
# ANTHROPIC_API_KEY 에 값을 저장

# %%
import anthropic

client = anthropic.Anthropic()

message = client.messages.create(
model="claude-sonnet-5",
max_tokens=1024,
messages=[
{"role": "user", "content": "너는누구야?"}
]
) 

print(message.content[0].text)

# %%
import anthropic
import os

client = anthropic.Anthropic(api_key= os.environ['ANTHROPIC_API_KEY'])

message = client.messages.create(
model="claude-sonnet-5",
max_tokens=1024,
messages=[
{"role": "user", "content": "너는누구야?"}
]
) 

print(message.content[0].text)
# Out:
# # 안녕하세요! 👋
#
# 저는 **Claude**입니다. Anthropic에서 개발한 AI 어시스턴트예요.
#
# ## 제가 할 수 있는 것들
#
# - 💬 **대화 및 질문 답변** - 다양한 주제에 대해 이야기 나누기
# - ✍️ **글쓰기 도움** - 이메일, 에세이, 콘텐츠 작성 및 편집
# - 💻 **코딩 지원** - 프로그래밍 문제 해결, 코드 리뷰, 디버깅
# - 🔍 **분석 및 요약** - 문서 분석, 정보 요약
# - 🌐 **번역** - 여러 언어 간 번역
# - 🧮 **문제 해결** - 수학, 논리적 사고가 필요한 문제
#
# ## 참고하실 점
#
# - 실시간 인터넷 검색은 못하지만, 특정 지식 시점까지의 정보를 알고 있어요
# - 완벽하지 않을 수 있으니 중요한 정보는 확인해 보시는 걸 추천해요
# - 한국어로 편하게 대화하셔도 됩니다!
#
# 무엇을 도와드릴까요? 궁금한 점이나 필요한 게 있으면 말씀해 주세요! 😊
